# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# accuracy
# data = pd.DataFrame({
#     'Group':['Baseline','K = 3','K = 5','K = 8','CNN'],
#     'Mean':[0.787,0.8203333333,0.8191,0.8237666667,0.7925333333],
#     'SD':[0,0.01899850871,0.005232590181,0.008220908303,0.004461315202]
# })

# loss
data = pd.DataFrame({
    'Group':['K = 3','K = 5','K = 8','CNN'],
    'Mean':[0.5695666667,0.84875,0.9334666667,0.5722333333],
    'SD':[0.05261979982,0.01718269478,0.1237821204,0.00542709253]
})

palette = sns.cubehelix_palette(n_colors=len(data),as_cmap=True)#, start=2, rot=0, dark=0.2, light=0.8, as_cmap=True)

# Create a bar plot with error bars
sns.set(style="darkgrid")
plt.figure(figsize=(6.5, 6))
barplot = sns.barplot(x='Group', y='Mean', data=data, yerr=data['SD'], capsize=1)

# Apply the cubehelix color palette to the bars
for i, bar in enumerate(barplot.patches):
    bar.set_color(palette(i / len(data)))
    # plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{data['Mean'][i]:.3f}", 
    #          ha='center', va='bottom', fontsize=12)

# plt.title('Bar plot with error bars')
plt.ylim(0.5, 1)
plt.xlabel('Group', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# accuracy
data = pd.DataFrame({
    'Group':['Baseline','K = 3','K = 5','K = 8','CNN'],
    'Mean':[0.787,0.8203333333,0.8191,0.8237666667,0.7925333333],
    'SD':[0,0.01899850871,0.005232590181,0.008220908303,0.004461315202]
})

# loss
# data = pd.DataFrame({
#     'Group':['K = 3','K = 5','K = 8','CNN'],
#     'Mean':[0.5695666667,0.84875,0.9334666667,0.5722333333],
#     'SD':[0.05261979982,0.01718269478,0.1237821204,0.00542709253]
# })

palette = sns.cubehelix_palette(n_colors=len(data),as_cmap=True)#, start=2, rot=0, dark=0.2, light=0.8, as_cmap=True)

# Create a bar plot with error bars
sns.set(style="darkgrid")
plt.figure(figsize=(6.5, 6))
barplot = sns.barplot(x='Group', y='Mean', data=data, yerr=data['SD'], capsize=1)

# Apply the cubehelix color palette to the bars
for i, bar in enumerate(barplot.patches):
    bar.set_color(palette(i / len(data)))
    # plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{data['Mean'][i]:.3f}", 
    #          ha='center', va='bottom', fontsize=12)

# plt.title('Bar plot with error bars')
plt.ylim(0.75, 0.85)
plt.xlabel('Group', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %%
import numpy as np
from scipy.stats import ttest_ind

baseline = [.787,.787,.787]
k3 = [0.7985,0.8294,0.8331]
k5 = [0.8228,0.8228,0.8228]
k8 = [0.8176,0.8206,0.8331]
cnn = [0.796,0.7875,0.7941]

# baseline,k3 *
# baseline,k5 *
# baseline,k8 ***
# k5,cnn check
# k8,cnn ***

t_stat, p_val = ttest_ind(baseline, k8)

# %%
p_val
